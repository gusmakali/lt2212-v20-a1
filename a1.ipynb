# %% [markdown]
# ## Assignment 1 testing ground
#
# You can change what you want here, but we won't be evaluating it.  We will run the original version of this notebook plus any additional secret tests we deem fit.

# %%
import a1
import matplotlib.pyplot as plt
# Out:
# tf    0.8994252873563219
# tfidf 0.9224137931034483

# %%
df = a1.part1_load("grain", "crude", 300)

# %%
df
# Out:
#       class              filename       the        of        to         s  \
# 0     grain  grain/article427.txt  0.015714  0.014286  0.008571  0.008571
# 1     grain  grain/article174.txt  0.002290  0.001527  0.004580  0.000000
# 2     grain  grain/article457.txt  0.017333  0.002667  0.010667  0.002667
# 3     grain  grain/article010.txt  0.008174  0.002725  0.005450  0.008174
# 4     grain  grain/article262.txt  0.012407  0.007444  0.004963  0.000000
# ...     ...                   ...       ...       ...       ...       ...
# 1155  crude  crude/article063.txt  0.006826  0.005119  0.005119  0.000000
# 1156  crude  crude/article106.txt  0.005478  0.001712  0.005135  0.002396
# 1157  crude  crude/article462.txt  0.003452  0.004603  0.002301  0.001151
# 1158  crude  crude/article304.txt  0.010335  0.004277  0.005346  0.002851
# 1159  crude  crude/article447.txt  0.006369  0.001592  0.005573  0.002389
#
#         tonnes        in         u     grain  ...       oil  gulf  nil  \
# 0     0.008571  0.007143  0.007143  0.004286  ...  0.000000   0.0  0.0
# 1     0.008397  0.000763  0.000000  0.000000  ...  0.000000   0.0  0.0
# 2     0.000000  0.000000  0.002667  0.001333  ...  0.000000   0.0  0.0
# 3     0.002725  0.000000  0.008174  0.000000  ...  0.000000   0.0  0.0
# 4     0.000000  0.004963  0.000000  0.004963  ...  0.000000   0.0  0.0
# ...        ...       ...       ...       ...  ...       ...   ...  ...
# 1155  0.000000  0.010239  0.000000  0.000000  ...  0.003413   0.0  0.0
# 1156  0.000000  0.004793  0.000342  0.000000  ...  0.003081   0.0  0.0
# 1157  0.000000  0.003452  0.000000  0.000000  ...  0.002301   0.0  0.0
# 1158  0.000000  0.004633  0.000713  0.000000  ...  0.001426   0.0  0.0
# 1159  0.000000  0.001592  0.000000  0.000000  ...  0.003185   0.0  0.0
#
#          crude  gas   lt   barrels       bpd      opec    barrel
# 0     0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000
# 1     0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000
# 4     0.000000  0.0  0.0  0.000000  0.000000  0.000000  0.000000
# ...        ...  ...  ...       ...       ...       ...       ...
# 1155  0.003413  0.0  0.0  0.003413  0.000000  0.000000  0.000000
# 1156  0.001027  0.0  0.0  0.000342  0.000685  0.002396  0.000000
# 1157  0.000000  0.0  0.0  0.000000  0.000000  0.005754  0.001151
# 1158  0.000000  0.0  0.0  0.000000  0.000000  0.000356  0.000000
# 1159  0.001592  0.0  0.0  0.000000  0.000000  0.000000  0.000000
#
# [1160 rows x 88 columns]

# %%
plot = a1.part2_vis(df, 5)

# %%
df2 = a1.part3_tfidf(df)

# %%
plot2 = a1.part2_vis(df2, 5)

# %% [markdown]
# You can do whatever else, including testing the bonus, here.
